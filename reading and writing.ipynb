# %%
import numpy as np
data1 = np.genfromtxt('01_data.csv', delimiter = ",", names = True, usecols=np.arange(0,12), dtype = None)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.

# %%
data1
# Out:
# array([(  0, 0, 3, b'"Braund', b' Mr. Owen Harris"', b'male', 22.  , 1, 0, b'A/5 21171',   7.25  , b''),
#        (  2, 1, 1, b'"Cumings', b' Mrs. John Bradley (Florence Briggs Thayer)"', b'female', 38.  , 1, 0, b'PC 17599',  71.2833, b'C85'),
#        (  3, 1, 3, b'"Heikkinen', b' Miss. Laina"', b'female', 26.  , 0, 0, b'STON/O2. 3101282',   7.925 , b''),
#        (  4, 1, 1, b'"Futrelle', b' Mrs. Jacques Heath (Lily May Peel)"', b'female', 35.  , 1, 0, b'113803',  53.1   , b'C123'),
#        (  5, 0, 3, b'"Allen', b' Mr. William Henry"', b'male', 35.  , 0, 0, b'373450',   8.05  , b''),
#        (  6, 0, 3, b'"Moran', b' Mr. James"', b'male',   nan, 0, 0, b'330877',   8.4583, b''),
#        (  7, 0, 1, b'"McCarthy', b' Mr. Timothy J"', b'male', 54.  , 0, 0, b'17463',  51.8625, b'E46'),
#        (  8, 0, 3, b'"Palsson', b' Master. Gosta Leonard"', b'male',  2.  , 3, 1, b'349909',  21.075 , b''),
# ...

# %%
data2 = np.genfromtxt('02_data.csv', delimiter = ',', names = True, dtype = None)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   """Entry point for launching an IPython kernel.

# %%
data2
# Out:
# array([(1, b'"ktm"', 123), (2, b'', 124)],
#       dtype=[('id', '<i8'), ('city', 'S5'), ('loc', '<i8')])

# %%
data2[0]
# Out:
# (1, b'"ktm"', 123)

# %%
data2[1]
# Out:
# (2, b'', 124)

# %%
data2 = np.genfromtxt('02_data.csv', delimiter = ',', names = True, dtype = (int, 'U8', int), encoding = 'UTF-8')

# %%
data2
# Out:
# array([(1, '"ktm"', 123), (2, '', 124)],
#       dtype=[('id', '<i8'), ('city', '<U8'), ('loc', '<i8')])
